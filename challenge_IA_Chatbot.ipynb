# %%
import pandas as pd

# --- PASSO 1: DEFINIR AS PERGUNTAS "REAIS" POR INTENÇÃO (INTENT) ---

intents_e_perguntas_hc = {
    "agendamento_remarcar": [
        "Como remarcar minha consulta?",
        "Quero mudar a data da minha consulta.",
        "Posso reagendar pelo aplicativo?",
        "Preciso trocar o dia do meu exame",
        "como faz pra mudar a data?",
        "perdi a data posso remarcar",
        "arrumei um emprego e nao posso ir nesse horario",
        "meu filho ficou doente, posso mudar o dia?",
        "tem como adiantar a consulta?",
        "quanto tempo demora pra conseguir outra data?",
        "liguei e ninguem atende, como remarco?",
        "recebi um sms pra confirmar mas quero mudar a data",
        "posso escolher o dia pra reagendar?",
        "queria um horario mais cedo"
    ],
    "absenteismo_consequencias": [
        "O que acontece se eu faltar à consulta?",
        "Posso remarcar se não compareci?",
        "Meu nome fica bloqueado se eu faltar?",
        "quais as consequencias de faltar?",
        "faltei e agora",
        "se eu nao for sou desconvocado?",
        "como faço pra justificar minha falta?",
        "tive uma emergencia e faltei, perco a vaga?",
        "meu nome vai pro final da fila se eu faltar?",
        "preciso de atestado pra justificar?",
        "o posto de saude disse que se eu faltar perco o tratamento",
        "até quando posso avisar que vou faltar sem dar problema?",
        "posso cancelar no mesmo dia?",
        "se eu faltar no exame de sangue posso ir no dia seguinte?"
    ],
    "tecnologia_ajuda": [
        "Não sei usar o celular para confirmar.",
        "Posso pedir ajuda para confirmar presença?",
        "Existe outra forma de confirmar sem celular?",
        "o aplicativo nao funciona no meu celular",
        "como confirmar sem ser pelo app",
        "sou idoso e nao consigo mexer nisso",
        "ajuda com o portal do paciente",
        "esqueci a senha do portal",
        "meu cpf ta dando erro no app",
        "onde eu baixo o aplicativo oficial?",
        "o site nao carrega no meu 3g",
        "precisa de internet pra usar o app?",
        "meu neto pode confirmar pra mim?",
        "posso confirmar por email?",
        "o link que mandaram por sms nao abre"
    ],
    "documentos_obrigatorios": [
        "Quais documentos levar na consulta?",
        "Preciso levar identidade no exame?",
        "Aceitam carteira de trabalho como documento?",
        "Posso apresentar documento digital?",
        "o q precisa levar no dia?",
        "tem q levar o cartao amarelo do hc?",
        "precisa do encaminhamento do posto?",
        "meu rg é muito antigo, serve?",
        "perdi meu rg posso levar cnh?",
        "e pra criança, o que leva de documento?",
        "precisa levar comprovante de endereço?",
        "meu cartao do sus é de outra cidade, tem problema?",
        "o cartao amarelo é o mesmo que o cartao sus?",
        "preciso levar os exames antigos que eu tenho?",
        "xerox do documento serve ou tem que ser original?"
    ],
    "resultados_exames": [
        "Como acessar meus resultados de exames?",
        "Recebo resultado pelo aplicativo?",
        "Quanto tempo demora para sair o resultado?",
        "Posso retirar o resultado impresso no hospital?",
        "cade o resultado do meu exame de sangue",
        "ver resultado online",
        "o resultado sai na hora?",
        "o médico consegue ver o resultado direto no sistema?",
        "outra pessoa pode retirar meu resultado?",
        "o que precisa pra um amigo pegar meu exame?",
        "o resultado do exame vai pro posto de saude automatico?",
        "como imprime o resultado do site?",
        "o resultado vem com laudo?",
        "perdi o protocolo pra retirar o exame, e agora?"
    ],
    "localizacao_hc": [
        "onde fica o hospital das clinicas?",
        "qual o endereço do hc?",
        "como chegar no incor?",
        "onde é o instituto da criança?",
        "qual estação de metrô mais próxima do hc?",
        "me perdi dentro do hospital"
    ],
    "custos_sus": [
        "A consulta é de graça?",
        "Preciso pagar pelo exame?",
        "O hospital atende pelo SUS?",
        "quanto custa a consulta?",
        "o tratamento é gratuito?",
        "o estacionamento é pago?",
        "e os remedios, eu pego de graça?",
        "se eu precisar de uma protese, o sus cobre?",
        "tem algum custo que o hospital não cobre?",
        "o atestado medico é cobrado?",
        "a alimentação ta inclusa na internação?",
        "se eu vier de outra cidade, tem ajuda de custo?"
    ],
    "preparo_exames": [
        "preciso fazer preparo para o exame?",
        "como me preparo para o exame de amanhã?",
        "tem que fazer jejum?",
        "quantas horas de jejum para exame de sangue?",
        "posso beber agua durante o jejum?",
        "meu remedio de pressão quebra o jejum?",
        "qual o preparo para endoscopia?",
        "precisa de preparo para ressonancia magnetica?",
        "não me deram o papel com as instruções do exame",
        "onde eu encontro o preparo do meu exame?",
        "tenho que tomar algum remedio antes?",
        "posso vir com qualquer roupa?",
        "o que acontece se eu não fizer o preparo certo?",
        "esqueci de fazer o preparo, perco o exame?"
    ]
}

# --- PASSO 2: CRIAR RESPOSTAS ESPECÍFICAS E DETALHADAS PARA CADA INTENÇÃO ---

respostas_hc = {
    "agendamento_remarcar": "A remarcação de consultas no HC varia de acordo com o instituto e a especialidade. Em alguns casos, pode ser feita pelo aplicativo Portal do Paciente HC, desde que solicitada com antecedência mínima (por exemplo, 2 dias) e sem faltas recentes. Em outros, é necessário comparecer pessoalmente ao setor de registro ou entrar em contato com o balcão de agendamento. Sempre que possível, avise ou cancele com antecedência para não perder a vaga.",

    "absenteismo_consequencias": "Se você faltar sem avisar, pode ter o agendamento cancelado ou restrições para reagendar, especialmente em casos de faltas repetidas. Alguns institutos bloqueiam reagendamentos quando há duas ausências consecutivas. Dependendo do caso, pode ser necessário conseguir um novo encaminhamento na sua Unidade Básica de Saúde (UBS). Sempre que não puder comparecer, informe o quanto antes para evitar problemas na continuidade do tratamento.",

    "tecnologia_ajuda": "O Portal do Paciente HC (site ou aplicativo) permite consultar agendamentos, visualizar resultados e, em alguns casos, reagendar consultas. Se tiver dificuldades com a tecnologia, utilize o telefone que aparece no seu comprovante de agendamento ou encaminhamento. Cada instituto do HC pode ter um número de contato específico.",

    "documentos_obrigatorios": "No dia da sua consulta, leve: 1) Documento oficial com foto (RG ou CNH); 2) Cartão do SUS (Cartão Nacional de Saúde), se tiver; 3) Encaminhamento médico (se for sua primeira consulta na especialidade); e 4) Se já possuir, o cartão do HC (cartão institucional). Em alguns institutos podem existir exigências adicionais, por isso é bom confirmar no seu comprovante de agendamento.",

    "resultados_exames": "Você pode acessar seus resultados de duas formas: 1) Online: pelo Portal do Paciente HC, usando CPF e data de nascimento; 2) Presencialmente: no guichê do instituto onde fez o exame, levando documento com foto e, se necessário, o protocolo do exame. Confira os horários de funcionamento do guichê antes de ir.",

    "localizacao_hc": "O Hospital das Clínicas da FMUSP tem diversos institutos. O endereço principal é: Av. Dr. Enéas de Carvalho Aguiar, 255 – Cerqueira César, São Paulo (próximo à estação Clínicas do Metrô – Linha 2 Verde). Alguns institutos importantes: InCor (cardiologia) fica na mesma avenida, nº 44; Instituto da Criança (ICr) fica ao lado do prédio principal; Instituto Central (PAMB) é o maior prédio do complexo. Sempre confira o endereço no seu comprovante de agendamento ou no Portal do Paciente HC para ter certeza do local correto.",

    "custos_sus": "Todo atendimento realizado no Hospital das Clínicas pelo Sistema Único de Saúde (SUS) é gratuito para o paciente. Isso inclui consultas, exames, internações e medicamentos fornecidos pelo hospital. Não há cobrança em atendimentos pelo SUS.",

    "preparo_exames": "Muitos exames exigem preparo especial, como jejum ou uso de medicações específicas. As orientações para o seu exame estão no comprovante de agendamento, em uma folha de instruções ou disponíveis no Portal do Paciente HC. Caso não tenha recebido ou esteja em dúvida, entre em contato com a central de agendamento do seu instituto. Seguir corretamente o preparo é fundamental para que o exame possa ser realizado."
}


# --- PASSO 3: CONSTRUIR O DATASET FINAL ---
faq_data = []
for intent, perguntas in intents_e_perguntas_hc.items():
    for pergunta in perguntas:
        faq_data.append({
            "intent": intent,
            "pergunta": pergunta,
            "resposta": respostas_hc[intent]
        })

df = pd.DataFrame(faq_data)
df = df[['pergunta', 'resposta', 'intent']]

output_path = "faq_dataset_hc_100_entries.csv"
df.to_csv(output_path, index=False)

print(f"Dataset final com {len(df)} exemplos foi salvo em: {output_path}")
print("\n--- Amostra do Dataset Gerado ---")
print(df.tail(5))
